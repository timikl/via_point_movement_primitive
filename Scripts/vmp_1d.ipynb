# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#rom scipy import spline

#mu = 1
#sigma = 2
#x = random.normal(mu, sigma, size=(2, 3))
#loc ... mu ... mean
#scale ... sigma ... standard deviation
#size ... matrix size#
#print(x)

#sns.distplot(random.normal(size=1000), hist=False)

# Input parameters to VMP
t0 = 0
t1 = 5
dt = 0.001

y0 = [0.3]
y1 = [0.8]

via_points_y = [0.5, 0.4, 0.6]
via_points_x = [0.5, 0.5, 0.5]

mean = np.mean(via_points_y)
std = np.std(via_points_y)

h_s = np.linspace(y0, y1, int(1//dt))

s = np.linspace(0,1, int(1 // dt))
plt.plot(s, h_s)

#Sredinska točka:
# Posamplamo 1 tocko iz distribucije
y_sampled = np.random.normal(loc=mean, scale=std)
plt.plot(via_points_x[0], y_sampled, 'ko')
#plt.show()
